# %% [markdown]
# ## 01. Lectura de datos y crear simple gráfico GR
#     ----- Aqui puede venir la explicación ---------

# %% [markdown]
# #Importar librerias necesarias
# from welly import Well
# from welly import Curve
# import matplotlib.pyplot as plt
# import warnings

# %%
#Omitir warnings del sistema
warnings.filterwarnings('ignore')
#Cargar un pozo en la variable 'well'
well = Well.from_las('data/P-129_out.las')

# %%
#Cargar la data de la columna GR en variable gr y plotearla
gr = well.data['GR']  # this is a subclassed NumPy array...
gr.plot()
